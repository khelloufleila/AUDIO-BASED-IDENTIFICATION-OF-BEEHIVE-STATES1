# %%
# python -m pip install SoundFile
import glob
import os
from info import i, printb, printr, printp, print
import glob
import os
import librosa
import pdb
import csv
import json
import re
import numpy as np
import random
import librosa.display
import IPython.display as ipd
from sklearn import preprocessing
from collections import Counter
from matplotlib import pyplot as plt
from info import i, printb, printr, printp, print
import muda
import jams
from sklearn import svm
import librosa
import keras
import scipy.io as sio
import io
#-----------------------------------parameters for CNN -----------------------------------#
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split 
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import itertools
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
#from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt
from keras.models import Sequential, Input, Model 
from keras.layers import Dense, Dropout, Flatten, Activation 
from keras.layers import Conv2D , MaxPooling2D
from keras.layers.normalization import BatchNormalization 
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix
from keras.models import Sequential, load_model
#-----------------------------------parameters for TTBOX -----------------------------------#
import timbre_descriptor as td
import numpy as np
import scipy as sc
import my_tools as mt
from collections import namedtuple
import scipy
import scipy.signal
from scipy.io import wavfile

import matplotlib
import swipep as swp             # used for sing le-F0 estimation
import warnings                 # used for warning removal
import time               # used performance benchmark
import librosa


from utils import get_list_samples_names, get_features_from_samples, write_Statelabels_from_beeNotBeelabels,raw_feature_fromSample, labels2binary , get_GT_labels_fromFiles, get_items2replicate, BalanceData_online, get_list_samples_name_MFCC, SVM_Classification_BeehiveSTATE , fit_and_evaluate,deep_model, plot_confusion_matrix, get_list_samples_name_TTBOX, Dense_Net, plot_accuracy_val_accuracy, read_HiveState_fromSampleName

# %%
#----------------------------------- parameters to change-----------------------------------#
block_size=1 # blocks of 1 second
thresholds=[0, 0.5]  # minimum length for nobee intervals: 0 or 5 seconds (creates one label file per threshold value)
path_audioFiles="C:\\Users\PC\python\Stage\To Bee or not to Bee_the annotated dataset"+os.sep  # path to audio files
annotations_path="C:\\Users\PC\python\Stage\To Bee or not to Bee_the annotated dataset"+os.sep # path to .lab files
path_save_audio_labels= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+os.sep  # path where to save audio segments and labels files.
#----------------------------------- parameters to change-----------------------------------#
path_workingFolder='C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+os.sep  # path where to save audio segments and labels files.
labels2read= 'state_labels'
feature = 'MFCCs20'
path_working_MFCCs20= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\MFCCs20_matrix.mat'+os.sep
path_working_TTBox= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\TTBox_matrix.mat'+os.sep
path_save_audio_MFCCs= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\MFCCs20_matrix.mat'+os.sep 
path_working_stft= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\stft_matrix.mat'+os.sep

nbits = 16;
MAX_VAL = pow(2,(nbits-1)) * 1.0;
class_names= ['missing queen', 'active' ]
#----------------------------------parameter for CNN -----------------------------------------------------------#
# Set early stopping critiria
pat=5 # this is the number of epocks with no improvment after which the training will stop 
early_stopping= EarlyStopping(monitor='val_loss', patience=pat, verbose=1 )
n_folds=4
epochs=5
batch_size=145
#----------------------------------------------------------------------------------------------#
# if path doesn't exist then create one !!!
if not os.path.exists(path_save_audio_labels):
    os.makedirs(path_save_audio_labels)

# %%
###load_audioFiles_saves_segments( path_audioFiles, path_save_audio_labels, block_size , thresholds, annotations_path, read_beeNotBee_annotations='yes', save_audioSegments='yes')  
# read only labels_BeeNotBee_th0.5
path_beeNotbee_labels = path_save_audio_labels + 'labels_BeeNotBee_th'+str(thresholds[1])+'.csv'
print("path_beeNotbee_labels: ",path_beeNotbee_labels)
# Out:
# [2020-05-18 23:51:51 RAM60.4% 0.29GB] path_beeNotbee_labels:  C:\Users\PC\python\Stage\dataset_BeeNoBee_2_second1sec\labels_BeeNotBee_th0.5.csv

# %%
#### reads labels beeNotBee files and creates corresponding states label file
#### liste= write_Statelabels_from_beeNotBeelabels(path_save_audio_labels, path_beeNotbee_labels, states=['active','missing queen','swarm' ])
#------------split nobee from the path_save_audio-------------------------------
#import os
#for i in range(len(liste)):
#    os.remove(path_save_audio_labels+liste[i]+'.wav')
#liste[0]  
#--------------------------------------------------------------------------------
sample_ids=get_list_samples_names(path_save_audio_labels) # get sample ids from audio segments folder.
print(len(sample_ids) )
# Out:
# [2020-05-26 20:50:22 RAM69.1% 0.08GB] 17295

# %%
#Calculate the MFCCs20 
##### X=get_features_from_samples(path_workingFolder, sample_ids, 'MFCCs20', 'NO', 0)

# Claculate the stft 
X=get_features_from_samples(path_workingFolder, sample_ids, 'stft', 'NO', 0)

# Claculate the cqt 
#X=get_features_from_samples(path_workingFolder, sample_ids, 'cqt', 'NO', 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-898240c606b1> in <module>
#       3
#       4 # Claculate the stft
# ----> 5 X=get_features_from_samples(path_workingFolder, sample_ids, 'stft', 'NO', 0)
#       6
#       7 # Claculate the cqt
#
# ~\python\Stage\Audio_based\utils.py in get_features_from_samples(path_audio_samples, sample_ids, raw_feature, normalization, high_level_features)
#     823
#     824         # raw feature extraction:
# --> 825         x = raw_feature_fromSample( path_audio_samples+sample, raw_feature ) # x.shape: (4, 20, 2584)
#     826
#     827
#
# ~\python\Stage\Audio_based\utils.py in raw_feature_fromSample(path_audio_sample, feature2extract)
#     411     # Short-time Fourier transform
#     412     elif 'stft' in feature2extract:
# --> 413         x= librosa.stft(s , sr=Fs)
#     414     # constante Q transform
#     415     elif 'cqt' in  feature2extract:
#
# TypeError: stft() got an unexpected keyword argument 'sr'

# %% [markdown]
# # MFCCs+SVM

# %%
X, labels , Y , sample_idss =get_list_samples_name_MFCC(path_save_audio_MFCCs )
y_concat, x_concat, sample_ids_concat= BalanceData_online(Y, X, sample_idss)
print("Reshape the data") 
x, y, z= x_concat.shape
X=x_concat.reshape(x, y*z)
Y=y_concat
Y.shape,X.shape
print('split the dataset') 
x_train= X[4519:]
x_test=X[: 4518]
y_test=Y[:4518]
y_train= Y[4519:]
#x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state = 2020, shuffle=False)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape )
CLF, Test_GroundT, Train_GroundT, Test_Preds, Train_Preds, Test_Preds_Proba, Train_Preds_Proba = SVM_Classification_BeehiveSTATE(x_train, y_train , x_test, y_test, kerneloption='rbf')
# Metrics
print("Accuracy: ", metrics.accuracy_score( Test_GroundT, Test_Preds))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Test_GroundT, Test_Preds))
# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Test_GroundT, Test_Preds))
# Out:
# [2020-05-18 23:16:59 RAM59.0% 0.42GB] (13183, 880) (4518, 880) (13183,) (4518,)
# [2020-05-18 23:16:59 RAM59.0% 0.42GB]
#
# [2020-05-18 23:16:59 RAM59.0% 0.42GB] Starting classification with SVM:
# [2020-05-18 23:16:59 RAM59.0% 0.42GB]
#
# [2020-05-18 23:16:59 RAM59.0% 0.42GB] classification Beehive State into : Active or Missing Queen
# [2020-05-18 23:35:14 RAM61.3% 0.46GB] Accuracy:  0.749667994687915
# [2020-05-18 23:35:14 RAM61.3% 0.46GB] Precision: 0.8057605332063794
# [2020-05-18 23:35:14 RAM61.4% 0.46GB] Recall: 0.9148648648648648

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(Test_GroundT, Test_Preds )
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix

plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='MFCCs + SVM Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
target_names=['missing_queen', 'active']
print ('\nClasification report MFCCs + SVM:\n', classification_report(Test_GroundT, Test_Preds , target_names=target_names))
# Out:
# [2020-05-18 23:39:18 RAM61.7% 0.46GB] Confusion matrix, without normalization
# [2020-05-18 23:39:18 RAM61.7% 0.46GB] [[   2  816]
#  [ 315 3385]]
# [2020-05-18 23:39:18 RAM61.7% 0.47GB] Normalized confusion matrix
# [2020-05-18 23:39:18 RAM61.7% 0.47GB] [[0.   1.  ]
#  [0.09 0.91]]
# [2020-05-18 23:39:18 RAM61.8% 0.47GB]
# Clasification report MFCCs + SVM:
#                 precision    recall  f1-score   support
#
# missing_queen       0.01      0.00      0.00       818
#        active       0.81      0.91      0.86      3700
#
#      accuracy                           0.75      4518
#     macro avg       0.41      0.46      0.43      4518
#  weighted avg       0.66      0.75      0.70      4518

# %% [markdown]
# # MFCCs+CNN:

# %%
# 
X, labels , Y , sample_idss =get_list_samples_name_MFCC(path_save_audio_MFCCs )
x_train= X[:10082]
y_train= Y[:10082]
sample_idss_train=sample_idss[:10082]
x_test=X[10083: ]
y_test=Y[10083:]
sample_idss_test=sample_idss[10083:]
y_train, x_train, sample_ids_train= BalanceData_online(y_train, x_train, sample_idss_train)
y_test, x_test, sample_ids_test= BalanceData_online(y_test, x_test, sample_idss_test)

print("Reshape the data")
x, y, z= x_train.shape
x_train= x_train.reshape(-1, 20, 44, 1)
y_train=y_train.reshape(-1, 1)

x, y, z= x_test.shape
x_test= x_test.reshape(-1, 20, 44, 1)
y_test=y_test.reshape(-1, 1)
print("split the dataset")  
# Convert features and corresponding classification labels into numpy arrays

x_train = np.array(x_train.tolist())
y_train = np.array(y_train.tolist())
x_test = np.array(x_test.tolist())
y_test = np.array(y_test.tolist())
# Encode the classification labels
le = LabelEncoder()
y_train = to_categorical(le.fit_transform(y_train)) 
y_test = to_categorical(le.fit_transform(y_test)) 

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
#x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.3, random_state = 2020, shuffle=False)
model=deep_model(( 20,44, 1))
model.summary()
# Out:
# [2020-05-21 23:18:30 RAM66.6% 1.36GB] Balancing training data:
# [2020-05-21 23:18:30 RAM66.6% 1.36GB] will randomly replicate samples from least represented class
# [2020-05-21 23:22:31 RAM66.5% 1.47GB] Balancing training data:
# [2020-05-21 23:22:31 RAM66.5% 1.47GB] will randomly replicate samples from least represented class
# [2020-05-21 23:23:31 RAM68.9% 1.56GB] Reshape the data
# [2020-05-21 23:23:31 RAM68.9% 1.56GB] split the dataset
# C:\Users\PC\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:251: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [2020-05-21 23:24:05 RAM67.0% 1.5GB] (15576, 20, 44, 1) (13112, 20, 44, 1) (15576, 2) (13112, 2)
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_193 (Conv2D)          (None, 20, 44, 16)        160
# _________________________________________________________________
# leaky_re_lu_289 (LeakyReLU)  (None, 20, 44, 16)        0
# _________________________________________________________________
# max_pooling2d_193 (MaxPoolin (None, 10, 22, 16)        0
# _________________________________________________________________
# conv2d_194 (Conv2D)          (None, 10, 22, 16)        2320
# _________________________________________________________________
# leaky_re_lu_290 (LeakyReLU)  (None, 10, 22, 16)        0
# _________________________________________________________________
# max_pooling2d_194 (MaxPoolin (None, 5, 11, 16)         0
# _________________________________________________________________
# conv2d_195 (Conv2D)          (None, 5, 11, 16)         784
# _________________________________________________________________
# leaky_re_lu_291 (LeakyReLU)  (None, 5, 11, 16)         0
# _________________________________________________________________
# max_pooling2d_195 (MaxPoolin (None, 3, 6, 16)          0
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, 3, 6, 16)          784
# _________________________________________________________________
# leaky_re_lu_292 (LeakyReLU)  (None, 3, 6, 16)          0
# _________________________________________________________________
# max_pooling2d_196 (MaxPoolin (None, 2, 3, 16)          0
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 2, 3, 16)          0
# _________________________________________________________________
# flatten_49 (Flatten)         (None, 96)                0
# _________________________________________________________________
# dense_145 (Dense)            (None, 256)               24832
# _________________________________________________________________
# leaky_re_lu_293 (LeakyReLU)  (None, 256)               0
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_146 (Dense)            (None, 32)                8224
# _________________________________________________________________
# leaky_re_lu_294 (LeakyReLU)  (None, 32)                0
# _________________________________________________________________
# dense_147 (Dense)            (None, 2)                 66
# =================================================================
# Total params: 37,170
# Trainable params: 37,170
# Non-trainable params: 0
# _________________________________________________________________

# %%
# define the model check point callback -> this will keep saving the model as a physical file 
model_checkpoint= ModelCheckpoint('cnn_bee_11.h5', verbose=1, save_best_only=True )

# define a function to fit the model
def fit_and_evaluate(train_x, val_x, train_y, val_y, EPOCHS=20, BATCH_SIZE=145 ):
    model=None
    model=deep_model(( 20,44, 1))
    results= model.fit(train_x, train_y, epochs=EPOCHS, batch_size= BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], verbose=1, validation_data=(val_x, val_y))
    print("Val Score :", model.evaluate(val_x, val_y))
    return results 
    
# save the model history in a list after fitting so we can plot later 
model_history=[]
for i in range(n_folds):
    print("Training on Fold :", i+1)
    #x_t, x_v, y_t, y_v = train_test_split(x_train, y_train, test_size=0.10, random_state = 2020)
    model_history.append(fit_and_evaluate(x_train, x_test, y_train, y_test, epochs, batch_size))
    print("============="*12, end="\n\n\n")
# Out:
# [2020-05-21 23:24:42 RAM67.0% 1.5GB] Training on Fold : 1
# Train on 15576 samples, validate on 13112 samples
# Epoch 1/20
# 15576/15576 [==============================] - ETA: 56s - loss: 3.6693 - accuracy: 0.517 - ETA: 35s - loss: 4.6906 - accuracy: 0.462 - ETA: 27s - loss: 4.2698 - accuracy: 0.466 - ETA: 24s - loss: 3.4541 - accuracy: 0.477 - ETA: 22s - loss: 2.9292 - accuracy: 0.499 - ETA: 20s - loss: 2.5877 - accuracy: 0.498 - ETA: 19s - loss: 2.3320 - accuracy: 0.503 - ETA: 18s - loss: 2.1457 - accuracy: 0.501 - ETA: 17s - loss: 1.9953 - accuracy: 0.505 - ETA: 17s - loss: 1.8690 - accuracy: 0.505 - ETA: 16s - loss: 1.7615 - accuracy: 0.514 - ETA: 16s - loss: 1.6762 - accuracy: 0.513 - ETA: 15s - loss: 1.6013 - accuracy: 0.518 - ETA: 15s - loss: 1.5379 - accuracy: 0.521 - ETA: 14s - loss: 1.4805 - accuracy: 0.526 - ETA: 14s - loss: 1.4294 - accuracy: 0.533 - ETA: 14s - loss: 1.3849 - accuracy: 0.536 - ETA: 13s - loss: 1.3430 - accuracy: 0.546 - ETA: 13s - loss: 1.3069 - accuracy: 0.551 - ETA: 13s - loss: 1.2717 - accuracy: 0.557 - ETA: 13s - loss: 1.2410 - accuracy: 0.562 - ETA: 13s - loss: 1.2095 - accuracy: 0.570 - ETA: 12s - loss: 1.1822 - accuracy: 0.575 - ETA: 12s - loss: 1.1550 - accuracy: 0.582 - ETA: 12s - loss: 1.1319 - accuracy: 0.586 - ETA: 12s - loss: 1.1116 - accuracy: 0.588 - ETA: 11s - loss: 1.0887 - accuracy: 0.593 - ETA: 11s - loss: 1.0664 - accuracy: 0.601 - ETA: 11s - loss: 1.0446 - accuracy: 0.609 - ETA: 11s - loss: 1.0221 - accuracy: 0.617 - ETA: 11s - loss: 1.0020 - accuracy: 0.623 - ETA: 11s - loss: 0.9822 - accuracy: 0.630 - ETA: 10s - loss: 0.9661 - accuracy: 0.635 - ETA: 10s - loss: 0.9530 - accuracy: 0.638 - ETA: 10s - loss: 0.9376 - accuracy: 0.642 - ETA: 10s - loss: 0.9218 - accuracy: 0.648 - ETA: 10s - loss: 0.9062 - accuracy: 0.654 - ETA: 10s - loss: 0.8918 - accuracy: 0.660 - ETA: 9s - loss: 0.8760 - accuracy: 0.666 - ETA: 9s - loss: 0.8602 - accuracy: 0.67 - ETA: 9s - loss: 0.8444 - accuracy: 0.67 - ETA: 9s - loss: 0.8281 - accuracy: 0.68 - ETA: 9s - loss: 0.8127 - accuracy: 0.69 - ETA: 9s - loss: 0.7997 - accuracy: 0.69 - ETA: 8s - loss: 0.8015 - accuracy: 0.69 - ETA: 8s - loss: 0.8033 - accuracy: 0.69 - ETA: 8s - loss: 0.7962 - accuracy: 0.69 - ETA: 8s - loss: 0.7875 - accuracy: 0.69 - ETA: 8s - loss: 0.7763 - accuracy: 0.70 - ETA: 8s - loss: 0.7660 - accuracy: 0.70 - ETA: 7s - loss: 0.7550 - accuracy: 0.71 - ETA: 7s - loss: 0.7430 - accuracy: 0.71 - ETA: 7s - loss: 0.7324 - accuracy: 0.72 - ETA: 7s - loss: 0.7220 - accuracy: 0.72 - ETA: 7s - loss: 0.7116 - accuracy: 0.72 - ETA: 7s - loss: 0.7014 - accuracy: 0.73 - ETA: 7s - loss: 0.6916 - accuracy: 0.73 - ETA: 6s - loss: 0.6823 - accuracy: 0.74 - ETA: 6s - loss: 0.6759 - accuracy: 0.74 - ETA: 6s - loss: 0.6719 - accuracy: 0.74 - ETA: 6s - loss: 0.6674 - accuracy: 0.74 - ETA: 6s - loss: 0.6593 - accuracy: 0.74 - ETA: 6s - loss: 0.6516 - accuracy: 0.75 - ETA: 6s - loss: 0.6433 - accuracy: 0.75 - ETA: 5s - loss: 0.6355 - accuracy: 0.75 - ETA: 5s - loss: 0.6284 - accuracy: 0.76 - ETA: 5s - loss: 0.6221 - accuracy: 0.76 - ETA: 5s - loss: 0.6173 - accuracy: 0.76 - ETA: 5s - loss: 0.6143 - accuracy: 0.76 - ETA: 5s - loss: 0.6109 - accuracy: 0.76 - ETA: 5s - loss: 0.6051 - accuracy: 0.76 - ETA: 4s - loss: 0.5985 - accuracy: 0.77 - ETA: 4s - loss: 0.5931 - accuracy: 0.77 - ETA: 4s - loss: 0.5862 - accuracy: 0.77 - ETA: 4s - loss: 0.5797 - accuracy: 0.77 - ETA: 4s - loss: 0.5743 - accuracy: 0.78 - ETA: 4s - loss: 0.5685 - accuracy: 0.78 - ETA: 4s - loss: 0.5621 - accuracy: 0.78 - ETA: 3s - loss: 0.5563 - accuracy: 0.78 - ETA: 3s - loss: 0.5511 - accuracy: 0.78 - ETA: 3s - loss: 0.5464 - accuracy: 0.79 - ETA: 3s - loss: 0.5412 - accuracy: 0.79 - ETA: 3s - loss: 0.5364 - accuracy: 0.79 - ETA: 3s - loss: 0.5318 - accuracy: 0.79 - ETA: 3s - loss: 0.5285 - accuracy: 0.79 - ETA: 2s - loss: 0.5254 - accuracy: 0.79 - ETA: 2s - loss: 0.5230 - accuracy: 0.80 - ETA: 2s - loss: 0.5196 - accuracy: 0.80 - ETA: 2s - loss: 0.5155 - accuracy: 0.80 - ETA: 2s - loss: 0.5110 - accuracy: 0.80 - ETA: 2s - loss: 0.5062 - accuracy: 0.80 - ETA: 2s - loss: 0.5012 - accuracy: 0.80 - ETA: 2s - lo ...
#
# Epoch 00001: val_loss improved from inf to 5.58775, saving model to cnn_bee_11.h5
# Epoch 2/20
# 15576/15576 [==============================] - ETA: 12s - loss: 0.0795 - accuracy: 0.965 - ETA: 14s - loss: 0.0505 - accuracy: 0.982 - ETA: 14s - loss: 0.0549 - accuracy: 0.983 - ETA: 14s - loss: 0.0490 - accuracy: 0.984 - ETA: 14s - loss: 0.0520 - accuracy: 0.980 - ETA: 13s - loss: 0.0577 - accuracy: 0.978 - ETA: 13s - loss: 0.0575 - accuracy: 0.978 - ETA: 13s - loss: 0.0530 - accuracy: 0.981 - ETA: 13s - loss: 0.0579 - accuracy: 0.978 - ETA: 13s - loss: 0.1078 - accuracy: 0.957 - ETA: 13s - loss: 0.1943 - accuracy: 0.932 - ETA: 12s - loss: 0.1892 - accuracy: 0.933 - ETA: 12s - loss: 0.1784 - accuracy: 0.938 - ETA: 12s - loss: 0.1713 - accuracy: 0.941 - ETA: 12s - loss: 0.1660 - accuracy: 0.942 - ETA: 12s - loss: 0.1588 - accuracy: 0.945 - ETA: 12s - loss: 0.1520 - accuracy: 0.948 - ETA: 12s - loss: 0.1458 - accuracy: 0.950 - ETA: 12s - loss: 0.1422 - accuracy: 0.952 - ETA: 12s - loss: 0.1380 - accuracy: 0.953 - ETA: 12s - loss: 0.1339 - accuracy: 0.955 - ETA: 12s - loss: 0.1295 - accuracy: 0.956 - ETA: 11s - loss: 0.1269 - accuracy: 0.957 - ETA: 11s - loss: 0.1228 - accuracy: 0.958 - ETA: 11s - loss: 0.1190 - accuracy: 0.960 - ETA: 11s - loss: 0.1154 - accuracy: 0.961 - ETA: 11s - loss: 0.1134 - accuracy: 0.962 - ETA: 11s - loss: 0.1125 - accuracy: 0.962 - ETA: 10s - loss: 0.1132 - accuracy: 0.962 - ETA: 10s - loss: 0.1142 - accuracy: 0.961 - ETA: 10s - loss: 0.1137 - accuracy: 0.961 - ETA: 10s - loss: 0.1124 - accuracy: 0.961 - ETA: 10s - loss: 0.1099 - accuracy: 0.962 - ETA: 10s - loss: 0.1085 - accuracy: 0.962 - ETA: 10s - loss: 0.1069 - accuracy: 0.963 - ETA: 9s - loss: 0.1054 - accuracy: 0.963 - ETA: 9s - loss: 0.1034 - accuracy: 0.96 - ETA: 9s - loss: 0.1015 - accuracy: 0.96 - ETA: 9s - loss: 0.0999 - accuracy: 0.96 - ETA: 9s - loss: 0.0977 - accuracy: 0.96 - ETA: 9s - loss: 0.0973 - accuracy: 0.96 - ETA: 8s - loss: 0.1009 - accuracy: 0.96 - ETA: 8s - loss: 0.1092 - accuracy: 0.96 - ETA: 8s - loss: 0.1094 - accuracy: 0.96 - ETA: 8s - loss: 0.1100 - accuracy: 0.96 - ETA: 8s - loss: 0.1100 - accuracy: 0.96 - ETA: 8s - loss: 0.1088 - accuracy: 0.96 - ETA: 8s - loss: 0.1070 - accuracy: 0.96 - ETA: 7s - loss: 0.1054 - accuracy: 0.96 - ETA: 7s - loss: 0.1039 - accuracy: 0.96 - ETA: 7s - loss: 0.1026 - accuracy: 0.96 - ETA: 7s - loss: 0.1009 - accuracy: 0.96 - ETA: 7s - loss: 0.0991 - accuracy: 0.96 - ETA: 7s - loss: 0.0986 - accuracy: 0.96 - ETA: 7s - loss: 0.0973 - accuracy: 0.96 - ETA: 7s - loss: 0.0971 - accuracy: 0.96 - ETA: 6s - loss: 0.0957 - accuracy: 0.96 - ETA: 6s - loss: 0.0949 - accuracy: 0.96 - ETA: 6s - loss: 0.0936 - accuracy: 0.96 - ETA: 6s - loss: 0.0927 - accuracy: 0.96 - ETA: 6s - loss: 0.0930 - accuracy: 0.96 - ETA: 6s - loss: 0.0928 - accuracy: 0.96 - ETA: 6s - loss: 0.0947 - accuracy: 0.96 - ETA: 5s - loss: 0.0951 - accuracy: 0.96 - ETA: 5s - loss: 0.0955 - accuracy: 0.96 - ETA: 5s - loss: 0.0976 - accuracy: 0.96 - ETA: 5s - loss: 0.0997 - accuracy: 0.96 - ETA: 5s - loss: 0.0985 - accuracy: 0.96 - ETA: 5s - loss: 0.0974 - accuracy: 0.96 - ETA: 5s - loss: 0.0965 - accuracy: 0.96 - ETA: 4s - loss: 0.0956 - accuracy: 0.96 - ETA: 4s - loss: 0.0948 - accuracy: 0.96 - ETA: 4s - loss: 0.0939 - accuracy: 0.96 - ETA: 4s - loss: 0.0930 - accuracy: 0.96 - ETA: 4s - loss: 0.0921 - accuracy: 0.96 - ETA: 4s - loss: 0.0911 - accuracy: 0.96 - ETA: 4s - loss: 0.0908 - accuracy: 0.96 - ETA: 3s - loss: 0.0902 - accuracy: 0.96 - ETA: 3s - loss: 0.0895 - accuracy: 0.96 - ETA: 3s - loss: 0.0885 - accuracy: 0.96 - ETA: 3s - loss: 0.0875 - accuracy: 0.96 - ETA: 3s - loss: 0.0869 - accuracy: 0.96 - ETA: 3s - loss: 0.0861 - accuracy: 0.97 - ETA: 3s - loss: 0.0852 - accuracy: 0.97 - ETA: 3s - loss: 0.0842 - accuracy: 0.97 - ETA: 2s - loss: 0.0836 - accuracy: 0.97 - ETA: 2s - loss: 0.0829 - accuracy: 0.97 - ETA: 2s - loss: 0.0821 - accuracy: 0.97 - ETA: 2s - loss: 0.0814 - accuracy: 0.97 - ETA: 2s - loss: 0.0809 - accuracy: 0.97 - ETA: 2s - loss: 0.0805 - accuracy: 0.97 - ETA: 2s - loss: 0.0817 - accuracy: 0.97 - ETA: 1s - loss: 0. ...
#
# Epoch 00002: val_loss did not improve from 5.58775
# Epoch 3/20
# 15576/15576 [==============================] - ETA: 12s - loss: 0.0311 - accuracy: 0.979 - ETA: 13s - loss: 0.0357 - accuracy: 0.982 - ETA: 13s - loss: 0.0336 - accuracy: 0.983 - ETA: 13s - loss: 0.0370 - accuracy: 0.984 - ETA: 13s - loss: 0.0330 - accuracy: 0.986 - ETA: 13s - loss: 0.0304 - accuracy: 0.987 - ETA: 13s - loss: 0.0274 - accuracy: 0.988 - ETA: 13s - loss: 0.0254 - accuracy: 0.988 - ETA: 13s - loss: 0.0271 - accuracy: 0.989 - ETA: 12s - loss: 0.0263 - accuracy: 0.989 - ETA: 12s - loss: 0.0246 - accuracy: 0.990 - ETA: 12s - loss: 0.0236 - accuracy: 0.990 - ETA: 12s - loss: 0.0230 - accuracy: 0.991 - ETA: 12s - loss: 0.0219 - accuracy: 0.991 - ETA: 12s - loss: 0.0214 - accuracy: 0.991 - ETA: 12s - loss: 0.0210 - accuracy: 0.991 - ETA: 12s - loss: 0.0210 - accuracy: 0.991 - ETA: 11s - loss: 0.0214 - accuracy: 0.991 - ETA: 11s - loss: 0.0245 - accuracy: 0.990 - ETA: 11s - loss: 0.0345 - accuracy: 0.987 - ETA: 11s - loss: 0.0433 - accuracy: 0.983 - ETA: 11s - loss: 0.0468 - accuracy: 0.982 - ETA: 11s - loss: 0.0458 - accuracy: 0.983 - ETA: 11s - loss: 0.0450 - accuracy: 0.983 - ETA: 11s - loss: 0.0441 - accuracy: 0.984 - ETA: 10s - loss: 0.0431 - accuracy: 0.984 - ETA: 10s - loss: 0.0417 - accuracy: 0.985 - ETA: 10s - loss: 0.0408 - accuracy: 0.985 - ETA: 10s - loss: 0.0396 - accuracy: 0.986 - ETA: 10s - loss: 0.0394 - accuracy: 0.986 - ETA: 10s - loss: 0.0389 - accuracy: 0.986 - ETA: 10s - loss: 0.0381 - accuracy: 0.986 - ETA: 10s - loss: 0.0372 - accuracy: 0.987 - ETA: 9s - loss: 0.0363 - accuracy: 0.987 - ETA: 9s - loss: 0.0354 - accuracy: 0.98 - ETA: 9s - loss: 0.0345 - accuracy: 0.98 - ETA: 9s - loss: 0.0337 - accuracy: 0.98 - ETA: 9s - loss: 0.0338 - accuracy: 0.98 - ETA: 9s - loss: 0.0338 - accuracy: 0.98 - ETA: 9s - loss: 0.0335 - accuracy: 0.98 - ETA: 8s - loss: 0.0332 - accuracy: 0.98 - ETA: 8s - loss: 0.0340 - accuracy: 0.98 - ETA: 8s - loss: 0.0351 - accuracy: 0.98 - ETA: 8s - loss: 0.0347 - accuracy: 0.98 - ETA: 8s - loss: 0.0343 - accuracy: 0.98 - ETA: 8s - loss: 0.0341 - accuracy: 0.98 - ETA: 8s - loss: 0.0344 - accuracy: 0.98 - ETA: 7s - loss: 0.0359 - accuracy: 0.98 - ETA: 7s - loss: 0.0356 - accuracy: 0.98 - ETA: 7s - loss: 0.0355 - accuracy: 0.98 - ETA: 7s - loss: 0.0351 - accuracy: 0.98 - ETA: 7s - loss: 0.0350 - accuracy: 0.98 - ETA: 7s - loss: 0.0344 - accuracy: 0.98 - ETA: 7s - loss: 0.0338 - accuracy: 0.98 - ETA: 6s - loss: 0.0337 - accuracy: 0.98 - ETA: 6s - loss: 0.0332 - accuracy: 0.98 - ETA: 6s - loss: 0.0328 - accuracy: 0.98 - ETA: 6s - loss: 0.0323 - accuracy: 0.98 - ETA: 6s - loss: 0.0320 - accuracy: 0.98 - ETA: 6s - loss: 0.0319 - accuracy: 0.98 - ETA: 6s - loss: 0.0325 - accuracy: 0.98 - ETA: 6s - loss: 0.0326 - accuracy: 0.98 - ETA: 5s - loss: 0.0327 - accuracy: 0.98 - ETA: 5s - loss: 0.0338 - accuracy: 0.98 - ETA: 5s - loss: 0.0344 - accuracy: 0.98 - ETA: 5s - loss: 0.0344 - accuracy: 0.98 - ETA: 5s - loss: 0.0345 - accuracy: 0.98 - ETA: 5s - loss: 0.0350 - accuracy: 0.98 - ETA: 5s - loss: 0.0346 - accuracy: 0.98 - ETA: 4s - loss: 0.0342 - accuracy: 0.98 - ETA: 4s - loss: 0.0338 - accuracy: 0.98 - ETA: 4s - loss: 0.0338 - accuracy: 0.98 - ETA: 4s - loss: 0.0338 - accuracy: 0.98 - ETA: 4s - loss: 0.0340 - accuracy: 0.98 - ETA: 4s - loss: 0.0343 - accuracy: 0.98 - ETA: 4s - loss: 0.0364 - accuracy: 0.98 - ETA: 4s - loss: 0.0408 - accuracy: 0.98 - ETA: 3s - loss: 0.0439 - accuracy: 0.98 - ETA: 3s - loss: 0.0437 - accuracy: 0.98 - ETA: 3s - loss: 0.0435 - accuracy: 0.98 - ETA: 3s - loss: 0.0434 - accuracy: 0.98 - ETA: 3s - loss: 0.0431 - accuracy: 0.98 - ETA: 3s - loss: 0.0428 - accuracy: 0.98 - ETA: 3s - loss: 0.0426 - accuracy: 0.98 - ETA: 2s - loss: 0.0421 - accuracy: 0.98 - ETA: 2s - loss: 0.0420 - accuracy: 0.98 - ETA: 2s - loss: 0.0420 - accuracy: 0.98 - ETA: 2s - loss: 0.0417 - accuracy: 0.98 - ETA: 2s - loss: 0.0415 - accuracy: 0.98 - ETA: 2s - loss: 0.0411 - accuracy: 0.98 - ETA: 2s - loss: 0.0408 - accuracy: 0.98 - ETA: 2s - loss: 0.0404 - accuracy: 0.98 - ETA: 1s - loss: 0.0400 ...
#
# Epoch 00003: val_loss did not improve from 5.58775
# Epoch 4/20
# 15576/15576 [==============================] - ETA: 12s - loss: 0.0174 - accuracy: 0.993 - ETA: 12s - loss: 0.0353 - accuracy: 0.986 - ETA: 13s - loss: 0.0317 - accuracy: 0.988 - ETA: 13s - loss: 0.0328 - accuracy: 0.989 - ETA: 12s - loss: 0.0304 - accuracy: 0.990 - ETA: 12s - loss: 0.0262 - accuracy: 0.992 - ETA: 12s - loss: 0.0245 - accuracy: 0.992 - ETA: 13s - loss: 0.0236 - accuracy: 0.992 - ETA: 12s - loss: 0.0301 - accuracy: 0.987 - ETA: 12s - loss: 0.0502 - accuracy: 0.983 - ETA: 12s - loss: 0.0482 - accuracy: 0.983 - ETA: 12s - loss: 0.0443 - accuracy: 0.985 - ETA: 12s - loss: 0.0419 - accuracy: 0.986 - ETA: 12s - loss: 0.0395 - accuracy: 0.987 - ETA: 12s - loss: 0.0369 - accuracy: 0.988 - ETA: 12s - loss: 0.0366 - accuracy: 0.988 - ETA: 11s - loss: 0.0348 - accuracy: 0.988 - ETA: 11s - loss: 0.0340 - accuracy: 0.988 - ETA: 11s - loss: 0.0332 - accuracy: 0.988 - ETA: 11s - loss: 0.0318 - accuracy: 0.989 - ETA: 11s - loss: 0.0304 - accuracy: 0.989 - ETA: 11s - loss: 0.0303 - accuracy: 0.989 - ETA: 11s - loss: 0.0296 - accuracy: 0.989 - ETA: 11s - loss: 0.0286 - accuracy: 0.989 - ETA: 10s - loss: 0.0284 - accuracy: 0.990 - ETA: 10s - loss: 0.0295 - accuracy: 0.989 - ETA: 10s - loss: 0.0287 - accuracy: 0.990 - ETA: 10s - loss: 0.0288 - accuracy: 0.990 - ETA: 10s - loss: 0.0283 - accuracy: 0.990 - ETA: 10s - loss: 0.0287 - accuracy: 0.989 - ETA: 10s - loss: 0.0319 - accuracy: 0.989 - ETA: 9s - loss: 0.0320 - accuracy: 0.989 - ETA: 9s - loss: 0.0319 - accuracy: 0.98 - ETA: 9s - loss: 0.0324 - accuracy: 0.98 - ETA: 9s - loss: 0.0328 - accuracy: 0.98 - ETA: 9s - loss: 0.0330 - accuracy: 0.98 - ETA: 9s - loss: 0.0324 - accuracy: 0.98 - ETA: 9s - loss: 0.0318 - accuracy: 0.98 - ETA: 8s - loss: 0.0310 - accuracy: 0.98 - ETA: 8s - loss: 0.0304 - accuracy: 0.98 - ETA: 8s - loss: 0.0298 - accuracy: 0.98 - ETA: 8s - loss: 0.0292 - accuracy: 0.99 - ETA: 8s - loss: 0.0288 - accuracy: 0.99 - ETA: 8s - loss: 0.0282 - accuracy: 0.99 - ETA: 8s - loss: 0.0276 - accuracy: 0.99 - ETA: 8s - loss: 0.0271 - accuracy: 0.99 - ETA: 7s - loss: 0.0265 - accuracy: 0.99 - ETA: 7s - loss: 0.0261 - accuracy: 0.99 - ETA: 7s - loss: 0.0256 - accuracy: 0.99 - ETA: 7s - loss: 0.0251 - accuracy: 0.99 - ETA: 7s - loss: 0.0251 - accuracy: 0.99 - ETA: 7s - loss: 0.0324 - accuracy: 0.99 - ETA: 7s - loss: 0.0386 - accuracy: 0.98 - ETA: 7s - loss: 0.0394 - accuracy: 0.98 - ETA: 6s - loss: 0.0392 - accuracy: 0.98 - ETA: 6s - loss: 0.0388 - accuracy: 0.98 - ETA: 6s - loss: 0.0383 - accuracy: 0.98 - ETA: 6s - loss: 0.0378 - accuracy: 0.98 - ETA: 6s - loss: 0.0374 - accuracy: 0.98 - ETA: 6s - loss: 0.0374 - accuracy: 0.98 - ETA: 6s - loss: 0.0371 - accuracy: 0.98 - ETA: 5s - loss: 0.0366 - accuracy: 0.98 - ETA: 5s - loss: 0.0362 - accuracy: 0.98 - ETA: 5s - loss: 0.0360 - accuracy: 0.98 - ETA: 5s - loss: 0.0356 - accuracy: 0.98 - ETA: 5s - loss: 0.0353 - accuracy: 0.98 - ETA: 5s - loss: 0.0350 - accuracy: 0.98 - ETA: 5s - loss: 0.0345 - accuracy: 0.98 - ETA: 5s - loss: 0.0343 - accuracy: 0.98 - ETA: 4s - loss: 0.0341 - accuracy: 0.98 - ETA: 4s - loss: 0.0338 - accuracy: 0.98 - ETA: 4s - loss: 0.0333 - accuracy: 0.98 - ETA: 4s - loss: 0.0334 - accuracy: 0.98 - ETA: 4s - loss: 0.0330 - accuracy: 0.98 - ETA: 4s - loss: 0.0326 - accuracy: 0.99 - ETA: 4s - loss: 0.0322 - accuracy: 0.99 - ETA: 3s - loss: 0.0319 - accuracy: 0.99 - ETA: 3s - loss: 0.0315 - accuracy: 0.99 - ETA: 3s - loss: 0.0311 - accuracy: 0.99 - ETA: 3s - loss: 0.0310 - accuracy: 0.99 - ETA: 3s - loss: 0.0310 - accuracy: 0.99 - ETA: 3s - loss: 0.0310 - accuracy: 0.99 - ETA: 3s - loss: 0.0313 - accuracy: 0.99 - ETA: 3s - loss: 0.0318 - accuracy: 0.99 - ETA: 2s - loss: 0.0316 - accuracy: 0.99 - ETA: 2s - loss: 0.0312 - accuracy: 0.99 - ETA: 2s - loss: 0.0310 - accuracy: 0.99 - ETA: 2s - loss: 0.0309 - accuracy: 0.99 - ETA: 2s - loss: 0.0306 - accuracy: 0.99 - ETA: 2s - loss: 0.0304 - accuracy: 0.99 - ETA: 2s - loss: 0.0300 - accuracy: 0.99 - ETA: 2s - loss: 0.0297 - accuracy: 0.99 - ETA: 1s - loss: 0.0295 - a ...
#
# Epoch 00004: val_loss did not improve from 5.58775
# Epoch 5/20
# 15576/15576 [==============================] - ETA: 12s - loss: 0.2168 - accuracy: 0.910 - ETA: 13s - loss: 0.2685 - accuracy: 0.906 - ETA: 13s - loss: 0.1801 - accuracy: 0.937 - ETA: 13s - loss: 0.1386 - accuracy: 0.951 - ETA: 12s - loss: 0.1144 - accuracy: 0.960 - ETA: 12s - loss: 0.0959 - accuracy: 0.966 - ETA: 12s - loss: 0.0831 - accuracy: 0.971 - ETA: 12s - loss: 0.0732 - accuracy: 0.975 - ETA: 12s - loss: 0.0655 - accuracy: 0.977 - ETA: 12s - loss: 0.0595 - accuracy: 0.980 - ETA: 12s - loss: 0.0542 - accuracy: 0.981 - ETA: 12s - loss: 0.0498 - accuracy: 0.983 - ETA: 12s - loss: 0.0465 - accuracy: 0.984 - ETA: 11s - loss: 0.0435 - accuracy: 0.985 - ETA: 11s - loss: 0.0413 - accuracy: 0.986 - ETA: 11s - loss: 0.0390 - accuracy: 0.987 - ETA: 11s - loss: 0.0377 - accuracy: 0.987 - ETA: 11s - loss: 0.0366 - accuracy: 0.988 - ETA: 11s - loss: 0.0366 - accuracy: 0.988 - ETA: 11s - loss: 0.0355 - accuracy: 0.988 - ETA: 11s - loss: 0.0340 - accuracy: 0.988 - ETA: 11s - loss: 0.0373 - accuracy: 0.988 - ETA: 10s - loss: 0.0369 - accuracy: 0.988 - ETA: 10s - loss: 0.0355 - accuracy: 0.988 - ETA: 10s - loss: 0.0346 - accuracy: 0.988 - ETA: 10s - loss: 0.0334 - accuracy: 0.989 - ETA: 10s - loss: 0.0328 - accuracy: 0.989 - ETA: 10s - loss: 0.0317 - accuracy: 0.989 - ETA: 10s - loss: 0.0306 - accuracy: 0.989 - ETA: 10s - loss: 0.0313 - accuracy: 0.989 - ETA: 10s - loss: 0.0304 - accuracy: 0.989 - ETA: 10s - loss: 0.0300 - accuracy: 0.989 - ETA: 9s - loss: 0.0293 - accuracy: 0.990 - ETA: 9s - loss: 0.0290 - accuracy: 0.99 - ETA: 9s - loss: 0.0288 - accuracy: 0.99 - ETA: 9s - loss: 0.0282 - accuracy: 0.99 - ETA: 9s - loss: 0.0277 - accuracy: 0.99 - ETA: 9s - loss: 0.0270 - accuracy: 0.99 - ETA: 9s - loss: 0.0265 - accuracy: 0.99 - ETA: 9s - loss: 0.0264 - accuracy: 0.99 - ETA: 9s - loss: 0.0276 - accuracy: 0.99 - ETA: 8s - loss: 0.0359 - accuracy: 0.98 - ETA: 8s - loss: 0.0377 - accuracy: 0.98 - ETA: 8s - loss: 0.0369 - accuracy: 0.98 - ETA: 8s - loss: 0.0375 - accuracy: 0.98 - ETA: 8s - loss: 0.0369 - accuracy: 0.98 - ETA: 8s - loss: 0.0362 - accuracy: 0.98 - ETA: 8s - loss: 0.0355 - accuracy: 0.98 - ETA: 8s - loss: 0.0349 - accuracy: 0.98 - ETA: 7s - loss: 0.0342 - accuracy: 0.98 - ETA: 7s - loss: 0.0338 - accuracy: 0.98 - ETA: 7s - loss: 0.0335 - accuracy: 0.98 - ETA: 7s - loss: 0.0329 - accuracy: 0.98 - ETA: 7s - loss: 0.0326 - accuracy: 0.98 - ETA: 7s - loss: 0.0322 - accuracy: 0.98 - ETA: 7s - loss: 0.0317 - accuracy: 0.98 - ETA: 7s - loss: 0.0314 - accuracy: 0.98 - ETA: 6s - loss: 0.0312 - accuracy: 0.98 - ETA: 6s - loss: 0.0307 - accuracy: 0.98 - ETA: 6s - loss: 0.0302 - accuracy: 0.98 - ETA: 6s - loss: 0.0300 - accuracy: 0.98 - ETA: 6s - loss: 0.0305 - accuracy: 0.98 - ETA: 6s - loss: 0.0303 - accuracy: 0.98 - ETA: 6s - loss: 0.0298 - accuracy: 0.99 - ETA: 5s - loss: 0.0294 - accuracy: 0.99 - ETA: 5s - loss: 0.0290 - accuracy: 0.99 - ETA: 5s - loss: 0.0286 - accuracy: 0.99 - ETA: 5s - loss: 0.0282 - accuracy: 0.99 - ETA: 5s - loss: 0.0278 - accuracy: 0.99 - ETA: 5s - loss: 0.0275 - accuracy: 0.99 - ETA: 5s - loss: 0.0273 - accuracy: 0.99 - ETA: 4s - loss: 0.0269 - accuracy: 0.99 - ETA: 4s - loss: 0.0266 - accuracy: 0.99 - ETA: 4s - loss: 0.0263 - accuracy: 0.99 - ETA: 4s - loss: 0.0259 - accuracy: 0.99 - ETA: 4s - loss: 0.0256 - accuracy: 0.99 - ETA: 4s - loss: 0.0254 - accuracy: 0.99 - ETA: 4s - loss: 0.0252 - accuracy: 0.99 - ETA: 3s - loss: 0.0250 - accuracy: 0.99 - ETA: 3s - loss: 0.0248 - accuracy: 0.99 - ETA: 3s - loss: 0.0252 - accuracy: 0.99 - ETA: 3s - loss: 0.0254 - accuracy: 0.99 - ETA: 3s - loss: 0.0259 - accuracy: 0.99 - ETA: 3s - loss: 0.0256 - accuracy: 0.99 - ETA: 3s - loss: 0.0254 - accuracy: 0.99 - ETA: 2s - loss: 0.0251 - accuracy: 0.99 - ETA: 2s - loss: 0.0248 - accuracy: 0.99 - ETA: 2s - loss: 0.0246 - accuracy: 0.99 - ETA: 2s - loss: 0.0244 - accuracy: 0.99 - ETA: 2s - loss: 0.0243 - accuracy: 0.99 - ETA: 2s - loss: 0.0242 - accuracy: 0.99 - ETA: 2s - loss: 0.0239 - accuracy: 0.99 - ETA: 1s - loss: 0.0237 - ...
#
# Epoch 00005: val_loss did not improve from 5.58775
# Epoch 6/20
# 15576/15576 [==============================] - ETA: 12s - loss: 0.0093 - accuracy: 1.000 - ETA: 12s - loss: 0.0057 - accuracy: 1.000 - ETA: 14s - loss: 0.0049 - accuracy: 1.000 - ETA: 13s - loss: 0.0039 - accuracy: 1.000 - ETA: 13s - loss: 0.0084 - accuracy: 0.998 - ETA: 13s - loss: 0.0113 - accuracy: 0.996 - ETA: 13s - loss: 0.0122 - accuracy: 0.996 - ETA: 13s - loss: 0.0110 - accuracy: 0.996 - ETA: 12s - loss: 0.0101 - accuracy: 0.996 - ETA: 12s - loss: 0.0103 - accuracy: 0.996 - ETA: 12s - loss: 0.0095 - accuracy: 0.996 - ETA: 12s - loss: 0.0095 - accuracy: 0.996 - ETA: 12s - loss: 0.0089 - accuracy: 0.996 - ETA: 12s - loss: 0.0105 - accuracy: 0.996 - ETA: 12s - loss: 0.0104 - accuracy: 0.996 - ETA: 12s - loss: 0.0098 - accuracy: 0.996 - ETA: 12s - loss: 0.0108 - accuracy: 0.996 - ETA: 11s - loss: 0.0109 - accuracy: 0.996 - ETA: 11s - loss: 0.0115 - accuracy: 0.996 - ETA: 11s - loss: 0.0110 - accuracy: 0.996 - ETA: 11s - loss: 0.0111 - accuracy: 0.996 - ETA: 11s - loss: 0.0108 - accuracy: 0.996 - ETA: 11s - loss: 0.0105 - accuracy: 0.996 - ETA: 11s - loss: 0.0101 - accuracy: 0.996 - ETA: 10s - loss: 0.0097 - accuracy: 0.996 - ETA: 10s - loss: 0.0094 - accuracy: 0.996 - ETA: 10s - loss: 0.0091 - accuracy: 0.996 - ETA: 10s - loss: 0.0088 - accuracy: 0.997 - ETA: 10s - loss: 0.0087 - accuracy: 0.997 - ETA: 10s - loss: 0.0087 - accuracy: 0.997 - ETA: 10s - loss: 0.0092 - accuracy: 0.996 - ETA: 10s - loss: 0.0130 - accuracy: 0.996 - ETA: 9s - loss: 0.0199 - accuracy: 0.994 - ETA: 9s - loss: 0.0256 - accuracy: 0.99 - ETA: 9s - loss: 0.0288 - accuracy: 0.99 - ETA: 9s - loss: 0.0282 - accuracy: 0.99 - ETA: 9s - loss: 0.0276 - accuracy: 0.99 - ETA: 9s - loss: 0.0270 - accuracy: 0.99 - ETA: 9s - loss: 0.0264 - accuracy: 0.99 - ETA: 9s - loss: 0.0259 - accuracy: 0.99 - ETA: 8s - loss: 0.0253 - accuracy: 0.99 - ETA: 8s - loss: 0.0247 - accuracy: 0.99 - ETA: 8s - loss: 0.0244 - accuracy: 0.99 - ETA: 8s - loss: 0.0239 - accuracy: 0.99 - ETA: 8s - loss: 0.0242 - accuracy: 0.99 - ETA: 8s - loss: 0.0243 - accuracy: 0.99 - ETA: 8s - loss: 0.0243 - accuracy: 0.99 - ETA: 7s - loss: 0.0240 - accuracy: 0.99 - ETA: 7s - loss: 0.0238 - accuracy: 0.99 - ETA: 7s - loss: 0.0236 - accuracy: 0.99 - ETA: 7s - loss: 0.0231 - accuracy: 0.99 - ETA: 7s - loss: 0.0229 - accuracy: 0.99 - ETA: 7s - loss: 0.0228 - accuracy: 0.99 - ETA: 7s - loss: 0.0224 - accuracy: 0.99 - ETA: 7s - loss: 0.0221 - accuracy: 0.99 - ETA: 6s - loss: 0.0219 - accuracy: 0.99 - ETA: 6s - loss: 0.0216 - accuracy: 0.99 - ETA: 6s - loss: 0.0212 - accuracy: 0.99 - ETA: 6s - loss: 0.0209 - accuracy: 0.99 - ETA: 6s - loss: 0.0206 - accuracy: 0.99 - ETA: 6s - loss: 0.0202 - accuracy: 0.99 - ETA: 6s - loss: 0.0200 - accuracy: 0.99 - ETA: 6s - loss: 0.0197 - accuracy: 0.99 - ETA: 5s - loss: 0.0195 - accuracy: 0.99 - ETA: 5s - loss: 0.0215 - accuracy: 0.99 - ETA: 5s - loss: 0.0230 - accuracy: 0.99 - ETA: 5s - loss: 0.0247 - accuracy: 0.99 - ETA: 5s - loss: 0.0249 - accuracy: 0.99 - ETA: 5s - loss: 0.0246 - accuracy: 0.99 - ETA: 5s - loss: 0.0244 - accuracy: 0.99 - ETA: 4s - loss: 0.0241 - accuracy: 0.99 - ETA: 4s - loss: 0.0238 - accuracy: 0.99 - ETA: 4s - loss: 0.0235 - accuracy: 0.99 - ETA: 4s - loss: 0.0232 - accuracy: 0.99 - ETA: 4s - loss: 0.0229 - accuracy: 0.99 - ETA: 4s - loss: 0.0226 - accuracy: 0.99 - ETA: 4s - loss: 0.0224 - accuracy: 0.99 - ETA: 4s - loss: 0.0221 - accuracy: 0.99 - ETA: 3s - loss: 0.0219 - accuracy: 0.99 - ETA: 3s - loss: 0.0217 - accuracy: 0.99 - ETA: 3s - loss: 0.0214 - accuracy: 0.99 - ETA: 3s - loss: 0.0211 - accuracy: 0.99 - ETA: 3s - loss: 0.0209 - accuracy: 0.99 - ETA: 3s - loss: 0.0207 - accuracy: 0.99 - ETA: 3s - loss: 0.0206 - accuracy: 0.99 - ETA: 2s - loss: 0.0204 - accuracy: 0.99 - ETA: 2s - loss: 0.0207 - accuracy: 0.99 - ETA: 2s - loss: 0.0208 - accuracy: 0.99 - ETA: 2s - loss: 0.0208 - accuracy: 0.99 - ETA: 2s - loss: 0.0206 - accuracy: 0.99 - ETA: 2s - loss: 0.0204 - accuracy: 0.99 - ETA: 2s - loss: 0.0203 - accuracy: 0.99 - ETA: 1s - loss: 0.0200 - ...
#
# Epoch 00006: val_loss did not improve from 5.58775
# Epoch 00006: early stopping
# 13112/13112 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 6s 463us/step
# [2020-05-21 23:26:39 RAM67.1% 1.5GB] Val Score : [12.153143024083416, 0.17251372337341309]
# [2020-05-21 23:26:39 RAM67.1% 1.5GB] ============================================================================================================================================================

# %%
#Load the model that was saved by ModelCheckpoint
model = load_model('cnn_bee_11.h5')
score= model.evaluate(x_test, y_test, verbose=1)
# Predict labels: 
predicted_classes= model.predict(x_test)
predicted_classes=np.argmax(np.round(predicted_classes), axis=1)
rounded_predictions = model.predict_classes(x_test, batch_size=128, verbose=0)
rounded_labels=np.argmax(y_test, axis=1)
rounded_predictions[1], rounded_labels[1]
# Out:
# 13112/13112 [==============================] - ETA: 42 - ETA: 15 - ETA: 11 - ETA: 10 - ETA: 9 - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 7s 499us/step
# (1, 0)

# %%
#plt.rcParams.update({'figure.max_open_warning': 0})
fig = plt.figure()
# Compute confusion matrix
cnf_matrix = confusion_matrix(rounded_labels, rounded_predictions)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix

plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='MFCCs+ CNN Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
target_names=['missing_queen', 'active']
print ('\nClasification report MFCCs+ CNN:\n', classification_report(rounded_labels, rounded_predictions, target_names=target_names ))
# Out:
# [2020-05-21 23:27:06 RAM67.1% 1.5GB] Confusion matrix, without normalization
# [2020-05-21 23:27:06 RAM67.1% 1.5GB] [[1813 4743]
#  [6141  415]]
# [2020-05-21 23:27:07 RAM67.1% 1.5GB] Normalized confusion matrix
# [2020-05-21 23:27:07 RAM67.1% 1.5GB] [[0.28 0.72]
#  [0.94 0.06]]
# [2020-05-21 23:27:07 RAM67.1% 1.5GB]
# Clasification report MFCCs+ CNN:
#                 precision    recall  f1-score   support
#
# missing_queen       0.23      0.28      0.25      6556
#        active       0.08      0.06      0.07      6556
#
#      accuracy                           0.17     13112
#     macro avg       0.15      0.17      0.16     13112
#  weighted avg       0.15      0.17      0.16     13112

# %% [markdown]
# # TTBOX+ SVM:

# %%
#path_workingFolder_=path_workingFolder='C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_1_second'+str(block_size)+'sec'+os.sep  # path where to save a
#X_ttbox =get_features_from_samples(path_workingFolder, sample_ids, 'TTBOX', 'NO', 0)

# %%
path_save_audio= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\ttb_mat'+os.sep 
X_ttbox,  labels_ttbox , Y_ttbox, sample_ids_ttbox= get_list_samples_name_TTBOX(path_save_audio, extension='.mat')
y_ttbox, x_ttbox, sample_ids_concat= BalanceData_online(Y_ttbox, X_ttbox, sample_ids_ttbox)
print("Reshape the data ")
x, y, z= x_ttbox.shape
x_ttbox=x_ttbox.reshape(x, y*z)
print("split the data ")
x_train= x_ttbox[4519:]
x_test=x_ttbox[: 4518]
y_test=y_ttbox[:4518]
y_train= y_ttbox[4519:]
CLF, Test_GroundT, Train_GroundT, Test_Preds, Train_Preds, Test_Preds_Proba, Train_Preds_Proba = SVM_Classification_BeehiveSTATE(x_train, y_train , x_test, y_test, kerneloption='rbf')
print("Accuracy: ", metrics.accuracy_score( Test_GroundT, Test_Preds))
# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(Test_GroundT, Test_Preds))
# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(Test_GroundT, Test_Preds))
# Out:
# [2020-05-19 00:42:56 RAM62.8% 0.32GB] Balancing training data:
# [2020-05-19 00:42:56 RAM62.8% 0.32GB] will randomly replicate samples from least represented class
# [2020-05-19 00:43:04 RAM62.2% 0.34GB] Reshape the data
# [2020-05-19 00:43:04 RAM62.2% 0.34GB] split the data
# [2020-05-19 00:43:04 RAM62.2% 0.34GB]
#
# [2020-05-19 00:43:04 RAM62.2% 0.34GB] Starting classification with SVM:
# [2020-05-19 00:43:04 RAM62.2% 0.34GB]
#
# [2020-05-19 00:43:04 RAM62.2% 0.34GB] classification Beehive State into : Active or Missing Queen
# [2020-05-19 00:46:23 RAM59.9% 0.35GB] Accuracy:  0.7470119521912351
# [2020-05-19 00:46:23 RAM59.9% 0.35GB] Precision: 0.9229242474363215
# [2020-05-19 00:46:23 RAM59.9% 0.35GB] Recall: 0.754054054054054

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(Test_GroundT, Test_Preds )
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix

plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='TTBOX + SVM Confusion matrix')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
target_names=['missing_queen', 'active']
print ('\nClasification report TTBOX + SVM:\n', classification_report(Test_GroundT, Test_Preds , target_names=target_names))
# Out:
# [2020-05-19 00:46:59 RAM61.0% 0.35GB] Confusion matrix, without normalization
# [2020-05-19 00:46:59 RAM61.0% 0.35GB] [[ 585  233]
#  [ 910 2790]]
# [2020-05-19 00:46:59 RAM61.0% 0.35GB] Normalized confusion matrix
# [2020-05-19 00:46:59 RAM61.0% 0.35GB] [[0.72 0.28]
#  [0.25 0.75]]
# [2020-05-19 00:46:59 RAM61.1% 0.36GB]
# Clasification report TTBOX + SVM:
#                 precision    recall  f1-score   support
#
# missing_queen       0.39      0.72      0.51       818
#        active       0.92      0.75      0.83      3700
#
#      accuracy                           0.75      4518
#     macro avg       0.66      0.73      0.67      4518
#  weighted avg       0.83      0.75      0.77      4518

# %% [markdown]
# # TTBOX+CNN:

# %% [markdown]
# # TTBOX +DenseNet

# %%
path_save_audio= 'C:\\Users\\PC\\python\\Stage\\dataset_BeeNoBee_2_second'+str(block_size)+'sec'+'\\ttb_mat'+os.sep 
X_ttbox,  labels_ttbox , Y_ttbox, sample_ids_ttbox= get_list_samples_name_TTBOX(path_save_audio, extension='.mat')
y_ttbox, x_ttbox, sample_ids_concat= BalanceData_online(Y_ttbox, X_ttbox, sample_ids_ttbox)
X_ttbox= x_ttbox.reshape(-1, 164, 1)
Y_ttbox=y_ttbox.reshape(-1, 1)
# Convert features and corresponding classification labels into numpy arrays
X_ttbox = np.array(X_ttbox.tolist())
Y_ttbox = np.array(Y_ttbox.tolist())
# Encode the classification labels
te = LabelEncoder()
y_ttbox = to_categorical(te.fit_transform(Y_ttbox)) 
# split the dataset 
# split the dataset 
train_x= X_ttbox[4519:]
test_x=X_ttbox[: 4518]
test_y=y_ttbox[:4518]
train_y= y_ttbox[4519:]
model2= Dense_Net((164, 1))
model2.summary()
# Out:
# [2020-05-19 00:59:54 RAM65.1% 0.77GB] Balancing training data:
# [2020-05-19 00:59:54 RAM65.1% 0.77GB] will randomly replicate samples from least represented class
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_12 (Flatten)         (None, 164)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 328)               54120
# _________________________________________________________________
# activation_1 (Activation)    (None, 328)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 328)               1312
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 328)               0
# _________________________________________________________________
# dense_35 (Dense)             (None, 328)               107912
# _________________________________________________________________
# activation_2 (Activation)    (None, 328)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 328)               1312
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 328)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 328)               107912
# _________________________________________________________________
# activation_3 (Activation)    (None, 328)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 328)               1312
# _________________________________________________________________
# dense_37 (Dense)             (None, 2)                 658
# =================================================================
# Total params: 274,538
# Trainable params: 272,570
# Non-trainable params: 1,968
# _________________________________________________________________

# %%
# Set early stopping critiria
pat=5 # this is the number of epocks with no improvment after which the training will stop 
early_stopping= EarlyStopping(monitor='val_loss', patience=pat, verbose=1 )

# define the model check point callback -> this will keep saving the model as a physical file 
model_checkpoint= ModelCheckpoint('DenseNet_bee_1.h5', verbose=1, save_best_only=True )

# define a function to fit the model

def fit_and_evaluate(train_x, val_x, train_y, val_y, EPOCHS=50, BATCH_SIZE=145 ):
    model=None
    model=Dense_Net(( 164,1 ))
    results= model.fit(train_x, train_y, epochs=EPOCHS, batch_size= BATCH_SIZE, callbacks=[early_stopping, model_checkpoint], verbose=1, validation_split=0.1)
    print("Val Score :", model.evaluate(val_x, val_y))
    return results 
# save the model history in a list after fitting so we can plot later 
model_history=[]
for i in range(n_folds):
    print("Training on Fold :", i+1)
    x_t, x_v, y_t, y_v = train_test_split(train_x, train_y, test_size=0.1, random_state = 2020)
    model_history.append(fit_and_evaluate(x_t, x_v, y_t, y_v, epochs, batch_size))
    print("============="*12, end="\n\n\n")

# %%
model2 = load_model('DenseNet_bee_1.h5')
model2.evaluate(test_x, test_y, verbose=1)
# Predict labels: 
predicted_classes= model2.predict(test_x)

predicted_classes=np.argmax(np.round(predicted_classes), axis=1)
rounded_predictions = model2.predict_classes(test_x, batch_size=128, verbose=0)
rounded_labels=np.argmax(test_y, axis=1)
# Out:
# 4518/4518 [==============================] - ETA: 13 - ETA: 0 - ETA:  - ETA:  - ETA:  - ETA:  - 0s 88us/step

# %%
fig = plt.figure()
# Compute confusion matrix
cnf_matrix = confusion_matrix(rounded_labels, rounded_predictions)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix

plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='TTBOX + DenseNet Confusion matrix')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
target_names=['missing_queen', 'active']
print ('\nClasification report TTBOX+ DenseNet:\n', classification_report(rounded_labels, rounded_predictions, target_names=target_names ))
# Out:
# [2020-05-19 01:03:39 RAM71.9% 1.27GB] Confusion matrix, without normalization
# [2020-05-19 01:03:39 RAM71.9% 1.27GB] [[ 691  127]
#  [ 120 3580]]
# [2020-05-19 01:03:39 RAM71.9% 1.28GB] Normalized confusion matrix
# [2020-05-19 01:03:39 RAM71.9% 1.28GB] [[0.84 0.16]
#  [0.03 0.97]]
# [2020-05-19 01:03:39 RAM71.9% 1.28GB]
# Clasification report TTBOX+ DenseNet:
#                 precision    recall  f1-score   support
#
# missing_queen       0.85      0.84      0.85       818
#        active       0.97      0.97      0.97      3700
#
#      accuracy                           0.95      4518
#     macro avg       0.91      0.91      0.91      4518
#  weighted avg       0.95      0.95      0.95      4518
